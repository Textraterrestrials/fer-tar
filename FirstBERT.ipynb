# %% [markdown]
# # SemEval-2020 Task 4: Commonsense Validation and Explanation

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1rlwPIErsvGcYYgM6s_FT9FDn9lcHzvVU?usp=sharing)

# %% [markdown]
# # 0. Getting started

# %%
# !nvidia-smi
# Out:
# Sun May 16 00:08:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/fer-tar
# Out:
# /content/gdrive/.shortcut-targets-by-id/1drN2cinzIyZ4ThABotRYWgVJfNq9n-5w/fer-tar

# %%
# !pip install -q pytorch_lightning
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 808kB 8.5MB/s
#      |████████████████████████████████| 112kB 34.1MB/s
#      |████████████████████████████████| 645kB 40.3MB/s
#      |████████████████████████████████| 829kB 52.4MB/s
#      |████████████████████████████████| 276kB 50.6MB/s
#      |████████████████████████████████| 1.3MB 49.9MB/s
#      |████████████████████████████████| 296kB 49.3MB/s
#      |████████████████████████████████| 143kB 54.3MB/s
#   Building wheel for future (setup.py) ... done
#      |████████████████████████████████| 2.3MB 8.2MB/s
#      |████████████████████████████████| 901kB 51.7MB/s
#      |████████████████████████████████| 3.3MB 51.3MB/s

# %% [markdown]
# ## 0.1. Imports

# %%
import importlib
import src.models
importlib.reload(src.models)
# Out:
# <module 'src.models' from '/content/gdrive/.shortcut-targets-by-id/1drN2cinzIyZ4ThABotRYWgVJfNq9n-5w/fer-tar/src/models.py'>

# %%
import pytorch_lightning as pl
from torch.utils.data import DataLoader
from my_scripts import data
from src import encoders
from src.models import BertClassifier

# %%
BATCH_SIZE = 32
EPOCHS = 15

# %%
train_ds, val_ds, test_ds = data.ComVEDataset.from_data_folder(x_transforms=[encoders.BertEncoder()])
train_dataloader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_ds, batch_size=len(val_ds))

from pytorch_lightning.callbacks.early_stopping import EarlyStopping
early_stop_callback = EarlyStopping(
   monitor='val_acc',
   min_delta=0.00,
   patience=5,
   verbose=False,
   mode='max'
)

model = BertClassifier()
trainer = pl.Trainer(max_epochs=EPOCHS, gpus=1, progress_bar_refresh_rate=20, callbacks=[EarlyStopping(monitor='val_loss')])
trainer.fit(model, train_dataloader, val_dataloader)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=570.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name        | Type      | Params
# ------------------------------------------
# 0 | transformer | BertModel | 109 M
# 1 | dropout     | Dropout   | 0
# 2 | linear      | Linear    | 769
# ------------------------------------------
# 109 M     Trainable params
# 0         Non-trainable params
# 109 M     Total params
# 437.932   Total estimated model params size (MB)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# tensor([[-0.8187, -0.4951, -0.8710,  ..., -0.8221, -0.6989,  0.6848],
#         [-0.8532, -0.4772, -0.9619,  ..., -0.8836, -0.7625,  0.7257],
#         [-0.8580, -0.4910, -0.8467,  ..., -0.7539, -0.7192,  0.7521],
#         ...,
#         [-0.9481, -0.5536, -0.7328,  ..., -0.1223, -0.7903,  0.9498],
#         [-0.6631, -0.0951,  0.4133,  ...,  0.3248, -0.4802,  0.8099],
#         [-0.6880, -0.2269, -0.2984,  ...,  0.1437, -0.5509,  0.8389]],
#        device='cuda:0')
# torch.Size([997, 768])
# torch.Size([997, 768])
# /content/gdrive/.shortcut-targets-by-id/1drN2cinzIyZ4ThABotRYWgVJfNq9n-5w/fer-tar/src/models.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   acc = torch.tensor((predictions == y_batch).float()).mean()
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# tensor([[-0.7433, -0.3317, -0.5954,  ..., -0.3961, -0.5286,  0.6616],
#         [-0.8603, -0.2486, -0.2096,  ...,  0.0085, -0.6660,  0.8671],
#         [-0.9037, -0.5260, -0.9647,  ..., -0.9182, -0.8227,  0.9241],
#         ...,
#         [-0.7999, -0.1787,  0.5748,  ...,  0.4539, -0.5435,  0.7433],
#         [-0.7867, -0.4267, -0.9255,  ..., -0.7802, -0.7507,  0.7914],
#         [-0.7762, -0.1443, -0.7648,  ..., -0.7090, -0.5523,  0.8106]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.9370, -0.4503, -0.9393,  ..., -0.7909, -0.7438,  0.9526],
#         [-0.8451, -0.3740, -0.8364,  ..., -0.8431, -0.6234,  0.8175],
#         [-0.6299, -0.2465, -0.1332,  ..., -0.3571, -0.5815,  0.6789],
#         ...,
#         [-0.8878, -0.3212, -0.6851,  ..., -0.6688, -0.6788,  0.7732],
#         [-0.9377, -0.4955, -0.9701,  ..., -0.8730, -0.7683,  0.9479],
#         [-0.7752, -0.2797, -0.7923,  ..., -0.6870, -0.6486,  0.8261]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8653, -0.2617, -0.3656,  ...,  0.0419, -0.6822,  0.8973],
#         [-0.5844, -0.2400,  0.1264,  ...,  0.0910, -0.5122,  0.8654],
#         [-0.8703, -0.2567, -0.2155,  ...,  0.0807, -0.6621,  0.9004],
#         ...,
#         [-0.9302, -0.5132, -0.8768,  ..., -0.8034, -0.6811,  0.9675],
#         [-0.8668, -0.5432, -0.9125,  ..., -0.7067, -0.6192,  0.8824],
#         [-0.7937, -0.4096, -0.8731,  ..., -0.3285, -0.5639,  0.7714]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8400, -0.2458, -0.8709,  ..., -0.8520, -0.6141,  0.9173],
#         [-0.8758, -0.3932, -0.4547,  ...,  0.0237, -0.6335,  0.9397],
#         [-0.5654, -0.5278, -0.9476,  ..., -0.3579, -0.7600,  0.7205],
#         ...,
#         [-0.9267, -0.4993, -0.9026,  ..., -0.8671, -0.7739,  0.8348],
#         [-0.9389, -0.4784, -0.7036,  ..., -0.7318, -0.6342,  0.8967],
#         [-0.7690, -0.4422, -0.9626,  ..., -0.6934, -0.7365,  0.9030]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8847, -0.5346, -0.9252,  ..., -0.6324, -0.8163,  0.9361],
#         [-0.8275, -0.5125, -0.7330,  ..., -0.5301, -0.6482,  0.8579],
#         [-0.9039, -0.3879, -0.6119,  ..., -0.1877, -0.7414,  0.9458],
#         ...,
#         [-0.8155, -0.4417, -0.8508,  ..., -0.5819, -0.7301,  0.8570],
#         [-0.9459, -0.6605, -0.9981,  ..., -0.9763, -0.8523,  0.9676],
#         [-0.8248, -0.6605, -0.9922,  ..., -0.8866, -0.7510,  0.8695]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8250, -0.4248, -0.7371,  ..., -0.6271, -0.7000,  0.9205],
#         [-0.8214, -0.5647, -0.9875,  ..., -0.9438, -0.7123,  0.8426],
#         [-0.5997, -0.4141, -0.9703,  ..., -0.9433, -0.5984,  0.7861],
#         ...,
#         [-0.8297, -0.4712, -0.9012,  ..., -0.8010, -0.6525,  0.7146],
#         [-0.8597, -0.5520, -0.9639,  ..., -0.8575, -0.7420,  0.8961],
#         [-0.8211, -0.5713, -0.9773,  ..., -0.9714, -0.6800,  0.7946]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8987, -0.6225, -0.9738,  ..., -0.8823, -0.8339,  0.9364],
#         [-0.9835, -0.7336, -0.8854,  ..., -0.8182, -0.7675,  0.9513],
#         [-0.7570, -0.3078, -0.3762,  ..., -0.4274, -0.4935,  0.6228],
#         ...,
#         [-0.8914, -0.5470, -0.9891,  ..., -0.9645, -0.7406,  0.8453],
#         [-0.9171, -0.6339, -0.9990,  ..., -0.9835, -0.8336,  0.9133],
#         [-0.7728, -0.3954, -0.5072,  ..., -0.2773, -0.6452,  0.9162]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.9456, -0.6273, -0.9937,  ..., -0.9614, -0.8099,  0.9567],
#         [-0.8532, -0.5761, -0.9915,  ..., -0.9730, -0.6694,  0.9250],
#         [-0.8908, -0.4267, -0.9699,  ..., -0.9393, -0.7019,  0.8819],
#         ...,
#         [-0.9377, -0.5965, -0.9938,  ..., -0.9808, -0.7608,  0.9769],
#         [-0.8977, -0.6170, -0.9866,  ..., -0.9728, -0.8234,  0.9242],
#         [-0.8304, -0.6843, -0.9699,  ..., -0.9537, -0.6154,  0.5437]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8162, -0.5452, -0.8995,  ..., -0.7180, -0.5053,  0.8256],
#         [-0.9506, -0.4776, -0.8863,  ..., -0.7046, -0.7738,  0.9415],
#         [-0.9505, -0.8101, -0.9997,  ..., -0.9980, -0.8595,  0.9736],
#         ...,
#         [-0.5456, -0.5485, -0.9740,  ..., -0.8619, -0.5528,  0.6968],
#         [-0.7874, -0.7394, -0.9993,  ..., -0.9928, -0.6985,  0.7755],
#         [-0.9144, -0.7981, -0.9993,  ..., -0.9842, -0.7546,  0.9334]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8209, -0.4436, -0.9552,  ..., -0.6016, -0.7367,  0.9034],
#         [-0.7484, -0.5311, -0.9948,  ..., -0.9841, -0.5617,  0.5860],
#         [-0.8798, -0.4892, -0.9671,  ..., -0.8673, -0.6430,  0.9445],
#         ...,
#         [-0.8745, -0.7653, -0.9979,  ..., -0.9846, -0.7201,  0.8948],
#         [-0.9691, -0.7540, -0.9863,  ..., -0.9035, -0.7922,  0.9392],
#         [-0.9257, -0.6048, -0.9531,  ..., -0.8251, -0.6637,  0.9416]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.9540, -0.6404, -0.9955,  ..., -0.9715, -0.8553,  0.9564],
#         [-0.8310, -0.7538, -0.9955,  ..., -0.9399, -0.7647,  0.9418],
#         [-0.8481, -0.6290, -0.9785,  ..., -0.9606, -0.7303,  0.6708],
#         ...,
#         [-0.7505, -0.4446, -0.9624,  ..., -0.7693, -0.6593,  0.8840],
#         [-0.8298, -0.5844, -0.9858,  ..., -0.9231, -0.7672,  0.8383],
#         [-0.9378, -0.4505, -0.8661,  ..., -0.8717, -0.7086,  0.8661]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8449, -0.5404, -0.9279,  ..., -0.7370, -0.7514,  0.8378],
#         [-0.7973, -0.1309, -0.7767,  ..., -0.7571, -0.4214,  0.7150],
#         [-0.5745, -0.3904, -0.7621,  ..., -0.6811, -0.6288,  0.7552],
#         ...,
#         [-0.8631, -0.7269, -0.8879,  ..., -0.8746, -0.8715,  0.9261],
#         [-0.8493, -0.3146, -0.8974,  ..., -0.8490, -0.6675,  0.7677],
#         [-0.8918, -0.3050, -0.1669,  ..., -0.0787, -0.6080,  0.9476]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.7542, -0.3151, -0.6025,  ..., -0.2519, -0.6270,  0.6736],
#         [-0.7221, -0.4908, -0.9766,  ..., -0.9213, -0.6038,  0.9174],
#         [-0.8804, -0.4902, -0.9671,  ..., -0.8844, -0.6990,  0.9199],
#         ...,
#         [-0.8658, -0.6176, -0.8787,  ..., -0.5695, -0.8211,  0.9507],
#         [-0.8609, -0.3179, -0.9524,  ..., -0.9313, -0.6645,  0.9494],
#         [-0.8161, -0.6580, -0.8886,  ..., -0.8679, -0.7466,  0.8568]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8811, -0.6041, -0.9786,  ..., -0.9130, -0.7963,  0.9212],
#         [-0.8205, -0.3537, -0.8375,  ..., -0.9048, -0.6940,  0.8286],
#         [-0.8418, -0.6423, -0.9768,  ..., -0.8897, -0.8167,  0.8729],
#         ...,
#         [-0.8980, -0.6396, -0.9427,  ..., -0.7629, -0.7721,  0.9238],
#         [-0.6255, -0.3210, -0.5326,  ..., -0.0968, -0.5300,  0.7032],
#         [-0.9594, -0.6096, -0.9306,  ..., -0.8917, -0.7429,  0.9722]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.7750, -0.4596, -0.6959,  ..., -0.4430, -0.6561,  0.8574],
#         [-0.8651, -0.4233, -0.9040,  ..., -0.7633, -0.7434,  0.9325],
#         [-0.8134, -0.7470, -0.9936,  ..., -0.9382, -0.8462,  0.9170],
#         ...,
#         [-0.9282, -0.6890, -0.9883,  ..., -0.8898, -0.8276,  0.8476],
#         [-0.7588, -0.5455, -0.7817,  ..., -0.0213, -0.6114,  0.7923],
#         [-0.6621, -0.3635, -0.9218,  ..., -0.8713, -0.2591,  0.4631]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.7840, -0.3479, -0.8289,  ..., -0.6459, -0.6326,  0.8409],
#         [-0.6417, -0.5211, -0.9546,  ..., -0.8467, -0.5968,  0.7671],
#         [-0.6635, -0.0515, -0.0846,  ..., -0.1352, -0.5185,  0.8657],
#         ...,
#         [-0.8538, -0.3041, -0.9317,  ..., -0.6610, -0.7356,  0.9259],
#         [-0.8029, -0.5760, -0.9893,  ..., -0.9565, -0.6284,  0.8073],
#         [-0.8581, -0.7025, -0.9873,  ..., -0.9767, -0.7341,  0.7254]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8229, -0.5014, -0.9798,  ..., -0.9673, -0.5419,  0.9384],
#         [-0.6322, -0.4500, -0.9343,  ..., -0.8314, -0.6862,  0.7332],
#         [-0.7298, -0.4818, -0.8718,  ..., -0.8747, -0.5638,  0.8065],
#         ...,
#         [-0.7428, -0.4731, -0.8855,  ..., -0.8940, -0.6334,  0.6832],
#         [-0.6790, -0.4068, -0.6870,  ..., -0.7109, -0.5499,  0.6978],
#         [-0.8274, -0.6393, -0.9700,  ..., -0.8409, -0.6677,  0.8793]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8349, -0.6212, -0.7613,  ..., -0.7816, -0.6649,  0.7839],
#         [-0.6889, -0.5343, -0.9032,  ..., -0.6632, -0.8076,  0.8674],
#         [-0.7342, -0.4004, -0.6876,  ..., -0.2513, -0.6717,  0.8035],
#         ...,
#         [-0.6324, -0.2815, -0.6664,  ..., -0.6965, -0.6090,  0.7406],
#         [-0.8358, -0.5562, -0.8809,  ..., -0.7930, -0.7449,  0.7506],
#         [-0.8013, -0.3160, -0.6965,  ..., -0.6319, -0.6180,  0.9393]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.5976, -0.1603,  0.6059,  ..., -0.1154, -0.2318,  0.6279],
#         [-0.8452, -0.5802, -0.9748,  ..., -0.9172, -0.7692,  0.8786],
#         [-0.4418, -0.5169, -0.6712,  ..., -0.8225, -0.6336,  0.5236],
#         ...,
#         [-0.7234, -0.4143, -0.8669,  ..., -0.8284, -0.7146,  0.8942],
#         [-0.3994, -0.4507, -0.9439,  ..., -0.9062, -0.5677,  0.6806],
#         [-0.6765, -0.5193, -0.8488,  ..., -0.7770, -0.6457,  0.7742]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.6743, -0.2690, -0.8245,  ..., -0.5848, -0.6923,  0.8306],
#         [-0.2918, -0.4557, -0.8865,  ..., -0.9127, -0.6148,  0.7518],
#         [-0.6103, -0.4334, -0.3605,  ..., -0.5425, -0.5264,  0.6208],
#         ...,
#         [-0.3674, -0.5355, -0.8241,  ..., -0.4225, -0.4390,  0.4781],
#         [-0.7801, -0.5594, -0.9368,  ..., -0.8336, -0.5878,  0.7639],
#         [ 0.0030, -0.2092, -0.6431,  ..., -0.5749, -0.4130,  0.4100]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.4647, -0.3002, -0.1087,  ..., -0.3106, -0.4726,  0.7874],
#         [-0.8415, -0.5044, -0.9172,  ..., -0.9398, -0.6494,  0.6781],
#         [-0.8877, -0.4347, -0.9032,  ..., -0.6614, -0.7776,  0.9157],
#         ...,
#         [-0.7032, -0.3895, -0.8608,  ..., -0.6587, -0.6456,  0.7763],
#         [-0.8374, -0.6097, -0.7642,  ..., -0.5430, -0.7139,  0.8512],
#         [-0.2063, -0.3018,  0.5040,  ...,  0.2343, -0.5030,  0.5217]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.1418, -0.3047, -0.3643,  ..., -0.6445, -0.4728,  0.4891],
#         [-0.7659, -0.4684, -0.2650,  ..., -0.5077, -0.6760,  0.8856],
#         [-0.4229, -0.3982, -0.7997,  ..., -0.7062, -0.4526,  0.7340],
#         ...,
#         [-0.6225, -0.3352, -0.7615,  ..., -0.7169, -0.5874,  0.9093],
#         [-0.7270, -0.3837, -0.6684,  ..., -0.5125, -0.6534,  0.4566],
#         [-0.5708, -0.3412, -0.3056,  ...,  0.2438, -0.5934,  0.8526]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.3515, -0.2784,  0.0972,  ..., -0.2383, -0.4867,  0.5358],
#         [-0.5113, -0.4155, -0.8045,  ..., -0.7001, -0.5978,  0.7807],
#         [-0.1323, -0.2679, -0.8650,  ..., -0.7653, -0.4973,  0.5322],
#         ...,
#         [-0.6652, -0.4055, -0.8881,  ..., -0.7459, -0.7123,  0.7702],
#         [-0.4095, -0.3194, -0.3425,  ..., -0.3815, -0.3677,  0.5529],
#         [-0.2198, -0.5006, -0.7432,  ..., -0.7713, -0.6161,  0.2911]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.2903, -0.3454, -0.8525,  ..., -0.4673, -0.4332,  0.4561],
#         [-0.4904, -0.3573, -0.0383,  ..., -0.5311, -0.5106,  0.3357],
#         [-0.6336, -0.3071, -0.5393,  ..., -0.2413, -0.6201,  0.8086],
#         ...,
#         [-0.8274, -0.5187, -0.9468,  ..., -0.8587, -0.7097,  0.7079],
#         [-0.7950, -0.2202,  0.3941,  ...,  0.1959, -0.5215,  0.9275],
#         [-0.1575, -0.4027,  0.3674,  ...,  0.2648, -0.5917,  0.4801]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.5794, -0.5315, -0.9650,  ..., -0.8484, -0.7679,  0.9001],
#         [-0.6047, -0.4502, -0.9616,  ..., -0.8746, -0.6474,  0.5419],
#         [-0.0052, -0.1594, -0.4960,  ..., -0.5714, -0.3240,  0.2172],
#         ...,
#         [-0.6564, -0.2584, -0.5353,  ..., -0.5181, -0.6084,  0.7903],
#         [-0.6725, -0.4280, -0.7039,  ...,  0.0235, -0.6485,  0.7447],
#         [-0.6140, -0.5479, -0.9854,  ..., -0.8869, -0.6100,  0.6447]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.4307, -0.4104, -0.9556,  ..., -0.8593, -0.6095,  0.3015],
#         [-0.4379, -0.4083, -0.6880,  ..., -0.0504, -0.5518,  0.6151],
#         [-0.7786, -0.3826, -0.8022,  ..., -0.6777, -0.6764,  0.7093],
#         ...,
#         [-0.1140, -0.0481,  0.3294,  ...,  0.6109, -0.4984,  0.6832],
#         [-0.8214, -0.1744, -0.6040,  ..., -0.4534, -0.5484,  0.7404],
#         [-0.4764, -0.3848, -0.8527,  ..., -0.6078, -0.5722,  0.7171]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.6016, -0.3175, -0.6215,  ..., -0.4062, -0.5858,  0.8884],
#         [-0.4756, -0.4485, -0.8904,  ..., -0.5729, -0.6264,  0.7175],
#         [ 0.1159,  0.0182,  0.9276,  ...,  0.8999, -0.3500,  0.6540],
#         ...,
#         [-0.0761, -0.0447,  0.2014,  ...,  0.6318, -0.5768,  0.5629],
#         [-0.5641, -0.3573, -0.7179,  ..., -0.3157, -0.7464,  0.7857],
#         [-0.8521, -0.4599, -0.8652,  ..., -0.5567, -0.6910,  0.9402]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.2318, -0.3514, -0.6783,  ..., -0.5253, -0.4345,  0.4718],
#         [-0.5853, -0.2521, -0.1096,  ..., -0.0819, -0.6234,  0.7587],
#         [-0.5237, -0.0196,  0.0868,  ...,  0.1421, -0.6035,  0.6317],
#         ...,
#         [-0.5910, -0.3710, -0.1036,  ..., -0.3632, -0.6556,  0.6411],
#         [-0.5458, -0.2500, -0.9212,  ..., -0.9016, -0.5043,  0.3196],
#         [-0.5224, -0.2870, -0.8308,  ..., -0.7767, -0.5472,  0.5378]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.7661, -0.5286, -0.3913,  ..., -0.3504, -0.5794,  0.4713],
#         [-0.4886, -0.5523, -0.9352,  ..., -0.7794, -0.6983,  0.7290],
#         [-0.4696, -0.4885, -0.7855,  ..., -0.8460, -0.5816,  0.1749],
#         ...,
#         [-0.6044, -0.5449, -0.1611,  ..., -0.4197, -0.6586,  0.8789],
#         [-0.3212, -0.3142, -0.5304,  ..., -0.5949, -0.2965,  0.6720],
#         [ 0.3023, -0.5175, -0.5509,  ..., -0.5423, -0.4339,  0.0122]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.3889, -0.1468,  0.8184,  ...,  0.3868, -0.4221,  0.5482],
#         [-0.3945, -0.0637, -0.7295,  ..., -0.2765, -0.5909,  0.6214],
#         [-0.3481, -0.4054,  0.6718,  ...,  0.0031, -0.3968,  0.4030],
#         ...,
#         [-0.6083, -0.2002, -0.4484,  ..., -0.3744, -0.5326,  0.6527],
#         [-0.6236, -0.1666, -0.6764,  ..., -0.6831, -0.5158,  0.6365],
#         [-0.6624, -0.3289, -0.5114,  ..., -0.1637, -0.4501,  0.5819]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.8069, -0.2484, -0.8667,  ..., -0.8042, -0.6967,  0.7744],
#         [-0.3718, -0.3273, -0.0419,  ..., -0.2143, -0.6634,  0.8041],
#         [-0.6602, -0.3354, -0.4044,  ..., -0.1818, -0.5678,  0.7096],
#         ...,
#         [-0.6273, -0.3376, -0.6104,  ..., -0.5647, -0.6960,  0.7724],
#         [-0.8081, -0.4488, -0.5948,  ..., -0.5901, -0.5487,  0.8727],
#         [-0.6852, -0.2336, -0.3244,  ...,  0.0923, -0.5945,  0.7405]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.7032, -0.3318, -0.7041,  ..., -0.4331, -0.6452,  0.8551],
#         [ 0.0615, -0.3116,  0.2437,  ...,  0.0955, -0.4373, -0.2549],
#         [-0.7234, -0.2754, -0.5321,  ..., -0.2125, -0.5714,  0.6226],
#         ...,
#         [-0.5006, -0.3299,  0.2227,  ...,  0.0738, -0.4178,  0.6630],
#         [-0.8165, -0.3764, -0.9313,  ..., -0.4275, -0.7425,  0.8836],
#         [-0.5775, -0.4528, -0.4276,  ..., -0.2780, -0.6778,  0.6707]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.7630, -0.4345, -0.8745,  ..., -0.2995, -0.7187,  0.8739],
#         [-0.7002, -0.6291, -0.9537,  ..., -0.8353, -0.8256,  0.7217],
#         [-0.8209, -0.3536, -0.6137,  ..., -0.5098, -0.6686,  0.8133],
#         ...,
#         [-0.7133, -0.3051, -0.3292,  ...,  0.0903, -0.4805,  0.6861],
#         [-0.1380, -0.5448, -0.8611,  ..., -0.6035, -0.4665,  0.4541],
#         [-0.0098, -0.2216, -0.1464,  ..., -0.4383, -0.1899,  0.4601]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.1126, -0.2979, -0.5452,  ..., -0.7244, -0.2909,  0.5839],
#         [-0.4442, -0.3253, -0.3466,  ..., -0.2504, -0.5756,  0.6370],
#         [-0.6668, -0.4241, -0.6903,  ..., -0.6937, -0.3492,  0.7454],
#         ...,
#         [-0.5628, -0.5607, -0.8791,  ..., -0.8222, -0.5304,  0.4695],
#         [-0.3818, -0.1615, -0.7726,  ..., -0.6927, -0.4570,  0.6402],
#         [-0.7871, -0.4292, -0.4323,  ..., -0.0697, -0.6881,  0.9470]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# tensor([[-0.5860, -0.2440, -0.8211,  ..., -0.1780, -0.5626,  0.6919],
#         [-0.6662, -0.4122, -0.3291,  ..., -0.1968, -0.5790,  0.7562],
#         [-0.5543, -0.2343, -0.8095,  ..., -0.7683, -0.4191,  0.6358],
#         ...,
#         [-0.7794, -0.1319, -0.6104,  ..., -0.4868, -0.4681,  0.5932],
#         [-0.0642, -0.2595, -0.5992,  ...,  0.0584, -0.4650,  0.6066],
#         [-0.3970, -0.3681, -0.6323,  ..., -0.7188, -0.5442,  0.6238]],
#        device='cuda:0', grad_fn=<TanhBackward>)
# torch.Size([32, 768])
# torch.Size([32, 768])
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:69: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## 0.2. Getting the data

# %% [markdown]
# ## 0.3. Preprocessing
